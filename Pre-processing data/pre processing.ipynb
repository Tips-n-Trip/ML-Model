# %% [markdown]
# ## Import Library

# %%
# Untuk mengupload file
import os

# Untuk mengolah dataset
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### Upload File CSV jika ada dataset baru

# %%
#Upload dataset jika belum tersedia
from google.colab import files
 
uploaded = files.upload()

# %%
# Load
df = pd.read_csv('dataset_lokasi.csv')

# %% [markdown]
# ## Data Exploring
#
# *   List item
# *   List item

# %%
# Handle duplicates dan missing data
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %% [markdown]
# ### Eksplorasi Dataset

# %% [markdown]
# #### Data Lokasi / Place

# %%
df.head()

# %%
# Cek jumlah tempat wisata pada setiap kota
df.City.value_counts(ascending = False)

# %% [markdown]
# ## Visualisasi Data

# %%
sns.countplot(y='City', data=df)
plt.title('Perbandingan jumlah wisata pada setiap kota', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(df['Price'])
plt.title('Distribusi Harga Masuk Wisata', pad=20)
#plt.show()

# %%
# Simpan Dataset
df.to_csv('processed_dataset_lokasi.csv', index=False)
